# %%
raw_data = """
13	North Tutupan	2024	2					316.9	1090.4			
14	South Tutupan	2024	2					56.2	685.0			
15	North Paringin	2024	2						210.9			
16	Wara I	2024	2					243.8	1057.0			
17	Wara II	2024	2						326.5			
18	Batubara Hamarung	2024	4					32.4	78.9			
19	Batubara Piyait	2024	5					20.5	57.2			
20	Batubara Tawahan	2024	6					65.7	203.6			
21	Batubara Benhes 3	2024	10						555.0			
22	Batubara Long Wehea 1	2024	11						1110.0			
23	Batubara Long Wehea 2	2024	12						23.0			
24	Batubara Long Wehea 4	2024	13						177.0			
25	Batubara Long Wehea 3	2024	14						949.0			
26	Batubara Marah Kenyah 2	2024	15						454.0			
27	Batubara Benhes 2	2024	16						4.3			
28	Batubara Gunung Kembang	2024	7					148.9	357.6			
29	Kestrel Mine	2024	17					165.5	416.3			
30	Batubara Melapeh Baru 1	2024	220					23.5	182.7			
31	Batubara Danum Paro	2024	219									
32	Bumbun Block	2024	22					55.5	174.5			
33	Juloi Northwest	2024	22						629.9			
34	Luon Block	2024	21					17.7	50.9			
35	Dahlia Arwana	2024	23					5.6	15.0			
36	Haju Block	2024	19					1.5	3.4			
37	Bara Block	2024	19					10.8	14.9			
38	Lumpunut Block	2024	20					86.1	94.2			
""".strip()

# %%
raw_data
# Out:
# '13\tNorth Tutupan\t2024\t2\t\t\t\t\t316.9\t1090.4\t\t\t\n14\tSouth Tutupan\t2024\t2\t\t\t\t\t56.2\t685.0\t\t\t\n15\tNorth Paringin\t2024\t2\t\t\t\t\t\t210.9\t\t\t\n16\tWara I\t2024\t2\t\t\t\t\t243.8\t1057.0\t\t\t\n17\tWara II\t2024\t2\t\t\t\t\t\t326.5\t\t\t\n18\tBatubara Hamarung\t2024\t4\t\t\t\t\t32.4\t78.9\t\t\t\n19\tBatubara Piyait\t2024\t5\t\t\t\t\t20.5\t57.2\t\t\t\n20\tBatubara Tawahan\t2024\t6\t\t\t\t\t65.7\t203.6\t\t\t\n21\tBatubara Benhes 3\t2024\t10\t\t\t\t\t\t555.0\t\t\t\n22\tBatubara Long Wehea 1\t2024\t11\t\t\t\t\t\t1110.0\t\t\t\n23\tBatubara Long Wehea 2\t2024\t12\t\t\t\t\t\t23.0\t\t\t\n24\tBatubara Long Wehea 4\t2024\t13\t\t\t\t\t\t177.0\t\t\t\n25\tBatubara Long Wehea 3\t2024\t14\t\t\t\t\t\t949.0\t\t\t\n26\tBatubara Marah Kenyah 2\t2024\t15\t\t\t\t\t\t454.0\t\t\t\n27\tBatubara Benhes 2\t2024\t16\t\t\t\t\t\t4.3\t\t\t\n28\tBatubara Gunung Kembang\t2024\t7\t\t\t\t\t148.9\t357.6\t\t\t\n29\tKestrel Mine\t2024\t17\t\t\t\t\t165.5\t416.3\t\t\t\n30\tBatubara Melapeh Baru 1\t2024\t220\t\t\t\t\t23.5\t182.7\t\t\t\n31\tBatubara Danum Paro\t2024\t219\t\t\t\t\t\t\t\t\t\n32\tBumbun Block\t2024\t22\t\t\t\t\t55.5\t174.5\t\t\t\n33\tJuloi Northwest\t2024\t22\t\t\t\t\t\t629.9\t\t\t\n34\tLuon Block\t2024\t21\t\t\t\t\t17.7\t50.9\t\t\t\n35\tDahlia Arwana\t2024\t23\t\t\t\t\t5.6\t15.0\t\t\t\n36\tHaju Block\t2024\t19\t\t\t\t\t1.5\t3.4\t\t\t\n37\tBara Block\t2024\t19\t\t\t\t\t10.8\t14.9\t\t\t\n38\tLumpunut Block\t2024\t20\t\t\t\t\t86.1\t94.2'

# %%
rows = []
for line in raw_data.splitlines():
    fields = line.split("\t")
    
    # Safely parse and convert fields
    def parse_float(val): return float(val) if val.strip() else None
    def parse_int(val): return int(val) if val.strip() else None
    def parse_str(val): return val.strip() if val.strip() else None

    row = {
        "id": parse_int(fields[0]),
        "name": parse_str(fields[1]),
        "year": parse_int(fields[2]),
        "company_id": parse_int(fields[3]),
        "calorific_value": parse_str(fields[4]),
        "production_volume": parse_float(fields[5]),
        "overburden_removal_volume": parse_float(fields[6]),
        "strip_ratio": parse_float(fields[7]),
        "reserve": parse_float(fields[8]),
        "resource": parse_float(fields[9]),
        "province": parse_str(fields[10]) if len(fields) > 10 else None,
        "city": parse_str(fields[11]) if len(fields) > 11 else None,
        "mineral_type": parse_str(fields[12]) if len(fields) > 12 else None,
    }
    rows.append(row)

# %%
from db import Company, MiningSite
from peewee import (
    Model,
    SqliteDatabase)

db = SqliteDatabase('coal-db.sqlite')

# %%
with db.atomic():
    for batch in [rows[i:i+50] for i in range(0, len(rows), 50)]:
        MiningSite.insert_many(batch).execute()

# %%
import pandas as pd
from db import Company, MiningSite
from peewee import fn
import re
from tabulate import tabulate

# %%
companies = Company.select()
for company in companies:
    pass

ms = MiningSite.select()
for m in ms:
    pass

# %%
existing_companies = [re.sub(r'\b(PT|Tbk)\b', '', company.name).lower().strip() for company in companies]
# existing_companies = [company.name.lower().strip() for company in companies]

# %%
nameyearcompany_query = (
    MiningSite
    .select(
        Company.name,
        fn.CONCAT(Company.name, MiningSite.name, MiningSite.year).alias('nameyearcompany'),
        MiningSite  # selects all columns from MiningSite
    )
    .join(Company, on=(MiningSite.company == Company.id))
)
existing_nameyearcompany = [row.nameyearcompany for row in nameyearcompany_query]

# %%
c_df = pd.read_csv("Sample db - company_directory.csv")
ccp_df = pd.read_csv("Sample db - company_performance.csv")
ms_df = pd.read_csv("Sample db - mining_site.csv")

# %%
c_df.loc[c_df['company_type'] == "Owner", 'company_type'] = "Mine Owner"
excluded_companies = ("PT BUMA Internasional Grup Tbk", "PT Murawai Coal")
c_df = c_df[~c_df["name"].isin(excluded_companies)]
c_df['name_cleaned'] = c_df['name'].str.replace(r'\b(PT|Tbk)\b', '', regex=True).str.lower().str.strip()

# %%
c_df[~c_df['name_cleaned'].isin(existing_companies)]
# Out:
#       id                     name idx_ticker  parent company id  \
# 91    92       PT Adaro Indonesia        NaN               25.0
# 111  112       PT Anugerah Energi        NaN               50.0
# 128  129  PT Rimba Perkasa Utama         NaN                NaN
#
#      operation_province    operation_kabkot representative_address  \
# 91   Kalimantan Selatan  Tabalong, Balangan                    NaN
# 111    Sumatera Selatan                 NaN                    NaN
# 128                 NaN                 NaN                    NaN
#
#     company_type    key_operation activities  ... phone_number email  \
# 91    Mine Owner  Mining Services        NaN  ...          NaN   NaN
# 111   Mine Owner           Mining        NaN  ...          NaN   NaN
# 128   Contractor  Mining Services        NaN  ...          NaN   NaN
#
#     Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# 91          NaN          NaN          NaN          NaN          NaN
# 111         NaN          NaN          NaN          NaN          NaN
# 128         NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 18 Unnamed: 19         name_cleaned
# 91          NaN         NaN      adaro indonesia
# 111         NaN         NaN      anugerah energi
# 128         NaN         NaN  rimba perkasa utama
#
# [3 rows x 21 columns]

# %%
c_df = c_df[c_df['name_cleaned'].isin(existing_companies)]

# %%
cc_ccp_df = pd.merge(c_df[['id', 'name']], ccp_df[['company_id', 'mine_id']], left_on='id', right_on='company_id', how='inner')

# %%
cc_ccp_ms_df = pd.merge(cc_ccp_df, ms_df, left_on='mine_id', right_on='mine_id', how='inner')
cc_ccp_ms_df = cc_ccp_ms_df[cc_ccp_ms_df['year_measured'].notna()]
cc_ccp_ms_df['year_measured'] = cc_ccp_ms_df['year_measured'].astype(int)
cc_ccp_ms_df['nameyearcompany'] = (
    cc_ccp_ms_df['name_x'].astype(str) +
    cc_ccp_ms_df['name_y'].astype(str) +
    cc_ccp_ms_df['year_measured'].astype(str)
)

# %%
new_cc_ccp_ms_df = cc_ccp_ms_df[~cc_ccp_ms_df['nameyearcompany'].isin(existing_nameyearcompany)]
new_cc_ccp_ms_df
# Out:
#     id_x                     name_x  company_id  mine_id  id_y  \
# 0      2       PT Fajar Sakti Prima           2      1.0     1
# 1      3             PT Bara Tabang           3      1.0     1
# 5      7     PT Brian Anjat Sentosa           7      7.0     7
# 10    12      PT Perkasa Inakakerta          12      5.0     5
# 11    13  PT Wahana Baratama Mining          13      6.0     6
# 12    14        PT Teguh Sinarabadi          14      4.0     4
# 13    15   PT Firman Ketaun Perkasa          15      4.0     4
# 14    27              PT Lahai Coal          27      9.0     9
# 15    27              PT Lahai Coal          27     14.0    14
# 16    29            PT Kalteng Coal          29     10.0    10
# 17    30              PT Juloi Coal          30     11.0    11
# 18    30              PT Juloi Coal          30     13.0    13
# 19    31      PT Sumber Barito Coal          31     12.0    12
# 29    94       PT Semesta Centramas          94     29.0    29
# 30    95  PT Paramitha Cipta Sarana          95     29.0    29
# 31    96     PT Laskar Semesta Alam          96     29.0    29
# 32    97    PT Mustika Indah Permai          97     30.0    30
# 33   102       PT Gorby Putra Utama         102     36.0    36
# 34   103     PT Gorby Global Energi         103     36.0    36
# 35   104         PT Cipta Wana Dana         104     36.0    36
# 36   105            PT Gorby Energy         105     36.0    36
# 37   106               PT Alhasanie         106     37.0    37
# 38   107         PT Borneo Minerals         107     37.0    37
# 39   108     PT Diva Kencana Borneo         108     38.0    38
# 40   109      PT Karya Borneo Agung         109     38.0    38
# 41   110        PT Bara Karya Agung         110     38.0    38
# 42   111           PT Hanson Energy         111     39.0    39
# 43   111           PT Hanson Energy         111     39.0    39
# 44   113  PT Kalbara Energi Pratama         113     40.0    40
# 45   114       PT Ratna Utama Karya         114     40.0    40
#
#                                      name_y  year_measured  calorific_value  \
# 0                                    Tabang           2022              NaN
# 1                                    Tabang           2022              NaN
# 5                                       BAS           2022              NaN
# 10                       Perkasa Inakakerta           2022              NaN
# 11                          Wahana Baratama           2022              NaN
# 12  Teguh Sinar Abadi/Firman Ketaun Perkasa           2022              NaN
# 13  Teguh Sinar Abadi/Firman Ketaun Perkasa           2022              NaN
# 14                                     Haju           2021              NaN
# 15                                     Bara           2021              NaN
# 16                                     Luon           2021              NaN
# 17                                   Bumbun           2021              NaN
# 18                          Juloi Northwest           2021              NaN
# 19                            Dahlia Arwana           2021              NaN
# 29                            Balangan Coal           2023              NaN
# 30                            Balangan Coal           2023              NaN
# 31                            Balangan Coal           2023              NaN
# 32                                      MIP           2024              NaN
# 33                                   Mutara           2021              NaN
# 34                                   Mutara           2021              NaN
# 35                                   Mutara           2021              NaN
# 36                                   Mutara           2021              NaN
# 37                                    Kukar           2021              NaN
# 38                                    Kukar           2021              NaN
# 39                                    Kubar           2021              NaN
# 40                                    Kubar           2021              NaN
# 41                                    Kubar           2021              NaN
# 42                                      Oku           2021              NaN
# 43                                      Oku           2021              NaN
# 44                                    Berau           2021              NaN
# 45                                    Berau           2021              NaN
#
#     production_volume  overburden_removal_volume  strip_ratio  \
# 0                 NaN                        NaN          NaN
# 1                 NaN                        NaN          NaN
# 5                 NaN                        NaN          NaN
# 10                NaN                        NaN          NaN
# 11                NaN                        NaN          NaN
# 12                NaN                        NaN          NaN
# 13                NaN                        NaN          NaN
# 14                NaN                        NaN          NaN
# 15                NaN                        NaN          NaN
# 16                NaN                        NaN          NaN
# 17                NaN                        NaN          NaN
# 18                NaN                        NaN          NaN
# 19                NaN                        NaN          NaN
# 29                NaN                        NaN          NaN
# 30                NaN                        NaN          NaN
# 31                NaN                        NaN          NaN
# 32                NaN                        NaN          NaN
# 33                NaN                        NaN          NaN
# 34                NaN                        NaN          NaN
# 35                NaN                        NaN          NaN
# 36                NaN                        NaN          NaN
# 37                NaN                        NaN          NaN
# 38                NaN                        NaN          NaN
# 39                NaN                        NaN          NaN
# 40                NaN                        NaN          NaN
# 41                NaN                        NaN          NaN
# 42                NaN                        NaN          NaN
# 43                NaN                        NaN          NaN
# 44                NaN                        NaN          NaN
# 45                NaN                        NaN          NaN
#
#     resources_inferred  resources_indicated resources_measured  \
# 0                  NaN                  NaN                NaN
# 1                  NaN                  NaN                NaN
# 5                  NaN                  NaN                NaN
# 10                 NaN                  NaN                NaN
# 11                 NaN                  NaN                NaN
# 12                 NaN                  NaN                NaN
# 13                 NaN                  NaN                NaN
# 14                0.10                 0.40                  3
# 15                0.30                 4.00               10.6
# 16                6.90                19.30               24.7
# 17               56.40                57.80               60.4
# 18              360.30               269.60                  -
# 19                2.00                 6.50                6.5
# 29                 NaN                  NaN                NaN
# 30                 NaN                  NaN                NaN
# 31                 NaN                  NaN                NaN
# 32                2.30                29.10              329.6
# 33               54.70                78.10              131.7
# 34               54.70                78.10              131.7
# 35               54.70                78.10              131.7
# 36               54.70                78.10              131.7
# 37                4.51                 9.15              21.54
# 38                4.51                 9.15              21.54
# 39                6.20                15.41               20.3
# 40                6.20                15.41               20.3
# 41                6.20                15.41               20.3
# 42               75.80               119.00                220
# 43               75.80               119.00                220
# 44                 NaN                  NaN                NaN
# 45                 NaN                  NaN                NaN
#
#    reserves_proved reserves_probable            province  \
# 0              NaN               NaN    Kalimantan Timur
# 1              NaN               NaN    Kalimantan Timur
# 5              NaN               NaN    Kalimantan Timur
# 10             NaN               NaN    Kalimantan Timur
# 11             NaN               NaN  Kalimantan Selatan
# 12             NaN               NaN    Kalimantan Timur
# 13             NaN               NaN    Kalimantan Timur
# 14             1.5                 0   Kalimantan Tengah
# 15             7.6               3.2   Kalimantan Tengah
# 16               0              17.7   Kalimantan Tengah
# 17               0              55.5   Kalimantan Tengah
# 18               -                 -   Kalimantan Tengah
# 19               0               5.6   Kalimantan Tengah
# 29             NaN               NaN  Kalimantan Selatan
# 30             NaN               NaN  Kalimantan Selatan
# 31             NaN               NaN  Kalimantan Selatan
# 32            57.6              94.7    Sumatera Selatan
# 33           65.78              23.8    Sumatera Selatan
# 34           65.78              23.8    Sumatera Selatan
# 35           65.78              23.8    Sumatera Selatan
# 36           65.78              23.8    Sumatera Selatan
# 37            4.88              3.64    Kalimantan Timur
# 38            4.88              3.64    Kalimantan Timur
# 39            9.79              3.41    Kalimantan Timur
# 40            9.79              3.41    Kalimantan Timur
# 41            9.79              3.41    Kalimantan Timur
# 42           149.3              49.3    Sumatera Selatan
# 43           149.3              49.3    Sumatera Selatan
# 44             NaN               NaN    Kalimantan Timur
# 45             NaN               NaN    Kalimantan Timur
#
#                           city  \
# 0            Kutai Kartanegara
# 1            Kutai Kartanegara
# 5            Kutai Kartanegara
# 10                 Kutai Timur
# 11                       Satui
# 12                 Kutai Barat
# 13                 Kutai Barat
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 29                         NaN
# 30                         NaN
# 31                         NaN
# 32                         NaN
# 33  Musi Rawas, Musi Banyuasin
# 34  Musi Rawas, Musi Banyuasin
# 35  Musi Rawas, Musi Banyuasin
# 36  Musi Rawas, Musi Banyuasin
# 37                       Berau
# 38                       Berau
# 39                  West Kutai
# 40                  West Kutai
# 41                  West Kutai
# 42          Martapura, Balfour
# 43          Martapura, Balfour
# 44                       Berau
# 45                       Berau
#
#                                       nameyearcompany
# 0                      PT Fajar Sakti PrimaTabang2022
# 1                            PT Bara TabangTabang2022
# 5                       PT Brian Anjat SentosaBAS2022
# 10        PT Perkasa InakakertaPerkasa Inakakerta2022
# 11       PT Wahana Baratama MiningWahana Baratama2022
# 12  PT Teguh SinarabadiTeguh Sinar Abadi/Firman Ke...
# 13  PT Firman Ketaun PerkasaTeguh Sinar Abadi/Firm...
# 14                              PT Lahai CoalHaju2021
# 15                              PT Lahai CoalBara2021
# 16                            PT Kalteng CoalLuon2021
# 17                            PT Juloi CoalBumbun2021
# 18                   PT Juloi CoalJuloi Northwest2021
# 19             PT Sumber Barito CoalDahlia Arwana2021
# 29              PT Semesta CentramasBalangan Coal2023
# 30         PT Paramitha Cipta SaranaBalangan Coal2023
# 31            PT Laskar Semesta AlamBalangan Coal2023
# 32                     PT Mustika Indah PermaiMIP2024
# 33                     PT Gorby Putra UtamaMutara2021
# 34                   PT Gorby Global EnergiMutara2021
# 35                       PT Cipta Wana DanaMutara2021
# 36                          PT Gorby EnergyMutara2021
# 37                              PT AlhasanieKukar2021
# 38                        PT Borneo MineralsKukar2021
# 39                    PT Diva Kencana BorneoKubar2021
# 40                     PT Karya Borneo AgungKubar2021
# 41                       PT Bara Karya AgungKubar2021
# 42                            PT Hanson EnergyOku2021
# 43                            PT Hanson EnergyOku2021
# 44                 PT Kalbara Energi PratamaBerau2021
# 45                      PT Ratna Utama KaryaBerau2021

# %%
new_cc_ccp_ms_df.columns
# Out:
# Index(['name_x', 'company_id', 'name_y', 'year_measured', 'calorific_value',
#        'production_volume', 'overburden_removal_volume', 'strip_ratio',
#        'resources_inferred', 'resources_indicated', 'resources_measured',
#        'reserves_proved', 'reserves_probable', 'province', 'city',
#        'nameyearcompany'],
#       dtype='object')

# %%
def safe_value(val):
    return None if pd.isna(val) else val

for _, row in new_cc_ccp_ms_df.iterrows():

    q_company = Company.select().where(Company.name == row['name_x']).first()
    q_company_id = q_company.id if q_company else None

    mining_site = MiningSite(
        name=safe_value(row['name_y']),
        year=safe_value(row['year_measured']),
        company=q_company_id,
        calorific_value=safe_value(row['calorific_value']),
        production_volume=safe_value(row['production_volume']),
        overburden_removal_volume=safe_value(row['overburden_removal_volume']),
        strip_ratio=safe_value(row['strip_ratio']),
        province=safe_value(row['province']),
        city=safe_value(row['city'])
    )

    # mining_site.save()

# %%
fields_to_compare = [
    'name',
    'idx_ticker',
    'operation_province',
    'operation_kabkot',
    'representative_address',
    'company_type',
    'key_operation',
    'activities',
    'website',
    'phone_number',
    'email'
]

for _, row in existing_company_df.iterrows():
    company = Company.get_or_none(Company.name == row['name'])
    if company:
        differences = []
        for field in fields_to_compare:
            model_value = getattr(company, field)
            df_value = safe_value(row[field])

            if (model_value != df_value) and (df_value is not None):
                differences.append([field, model_value, df_value])
                # setattr(company, field, df_value) 

        if differences:
            # company.save()
            print(f"\nDifferences for company '{company.name}':")
            print(tabulate(differences, headers=["Field", "DB Value", "CSV Value"], tablefmt="grid"))
# Out:
# Differences for company 'PT Pada Idi':
# +------------------+--------------+--------------+
# | Field            | DB Value     | CSV Value    |
# +==================+==============+==============+
# | operation_kabkot | Barito Utara | North Barito |
# +------------------+--------------+--------------+
#
# Differences for company 'PT Kaltim Prima Coal':
# +------------------+------------+-------------+
# | Field            | DB Value   | CSV Value   |
# +==================+============+=============+
# | operation_kabkot |            | Kutai Timur |
# +------------------+------------+-------------+
# | phone_number     | 549-521155 | 054-9521155 |
# +------------------+------------+-------------+
#
# Differences for company 'Bumi Resources Minerals Tbk':
# +------------------------+------------+---------------------------------------------------------------------------------------------------------------------+
# | Field                  | DB Value   | CSV Value                                                                                                           |
# +========================+============+=====================================================================================================================+
# | representative_address |            | Bakrie Tower, 6th & 10th Floor, Kompleks Rasuna Epicentrum, Jl. H.R. Rasuna Said Kuningan, Jakarta 12940, Indonesia |
# +------------------------+------------+---------------------------------------------------------------------------------------------------------------------+
# | company_type           | Mine Owner | Holding                                                                                                             |
# +------------------------+------------+---------------------------------------------------------------------------------------------------------------------+
# | website                |            | www.bumiresourcesminerals.com                                                                                       |
# +------------------------+------------+---------------------------------------------------------------------------------------------------------------------+
# | phone_number           |            | 021-57945698                                                                                                        |
# +------------------------+------------+---------------------------------------------------------------------------------------------------------------------+
#
# Differences for company 'PT Mandiri Herindo Adiperkasa Tbk':
# +---------------+------------------------------+-----------------+
# | Field         | DB Value                     | CSV Value       |
# +===============+==============================+=================+
# | key_operation | Overburden Removal & Hauling | Mining Services |
# +---------------+------------------------------+-----------------+
#
# Differences for company 'PT Ratah Coal':
# +--------------------+------------------+-------------------+
# | Field              | DB Value         | CSV Value         |
# +====================+==================+===================+
# | operation_province | Kalimantan Timur | Kalimantan Tengah |
# +--------------------+------------------+-------------------+
#
# Differences for company 'PT Bhakti Energi Persada':
# +------------------+-------------+-----------------+
# | Field            | DB Value    | CSV Value       |
# +==================+=============+=================+
# | operation_kabkot | Kutai TImur | Kutai Timur     |
# +------------------+-------------+-----------------+
# | key_operation    | Mining      | Mining Services |
# +------------------+-------------+-----------------+
#
# Differences for company 'PT Gorby Putra Utama':
# +------------------+------------+----------------------------+
# | Field            | DB Value   | CSV Value                  |
# +==================+============+============================+
# | operation_kabkot |            | Musi Rawas, Musi Banyuasin |
# +------------------+------------+----------------------------+
#
# Differences for company 'PT Gorby Global Energi':
# +------------------+------------+----------------------------+
# | Field            | DB Value   | CSV Value                  |
# +==================+============+============================+
# | operation_kabkot |            | Musi Rawas, Musi Banyuasin |
# +------------------+------------+----------------------------+
#
# Differences for company 'PT Cipta Wana Dana':
# +------------------+------------+----------------------------+
# | Field            | DB Value   | CSV Value                  |
# +==================+============+============================+
# | operation_kabkot |            | Musi Rawas, Musi Banyuasin |
# +------------------+------------+----------------------------+
#
# Differences for company 'PT Gorby Energy':
# +------------------+------------+----------------------------+
# | Field            | DB Value   | CSV Value                  |
# +==================+============+============================+
# | operation_kabkot |            | Musi Rawas, Musi Banyuasin |
# +------------------+------------+----------------------------+
#
# Differences for company 'PT Alhasanie':
# +------------------+------------+-------------+
# | Field            | DB Value   | CSV Value   |
# +==================+============+=============+
# | operation_kabkot |            | Berau       |
# +------------------+------------+-------------+
#
# Differences for company 'PT Borneo Minerals':
# +------------------+------------+-------------+
# | Field            | DB Value   | CSV Value   |
# +==================+============+=============+
# | operation_kabkot |            | Berau       |
# +------------------+------------+-------------+
#
# Differences for company 'PT Diva Kencana Borneo':
# +------------------+------------+-------------+
# | Field            | DB Value   | CSV Value   |
# +==================+============+=============+
# | operation_kabkot |            | West Kutai  |
# +------------------+------------+-------------+
#
# Differences for company 'PT Karya Borneo Agung':
# +------------------+------------+-------------+
# | Field            | DB Value   | CSV Value   |
# +==================+============+=============+
# | operation_kabkot |            | West Kutai  |
# +------------------+------------+-------------+
#
# Differences for company 'PT Bara Karya Agung':
# +------------------+------------+-------------+
# | Field            | DB Value   | CSV Value   |
# +==================+============+=============+
# | operation_kabkot |            | West Kutai  |
# +------------------+------------+-------------+
#
# Differences for company 'PT Hanson Energy':
# +------------------+------------+--------------------+
# | Field            | DB Value   | CSV Value          |
# +==================+============+====================+
# | operation_kabkot |            | Martapura, Balfour |
# +------------------+------------+--------------------+
#
# Differences for company 'PT Kalbara Energi Pratama':
# +------------------+------------+-------------+
# | Field            | DB Value   | CSV Value   |
# +==================+============+=============+
# | operation_kabkot |            | Berau       |
# +------------------+------------+-------------+
#
# Differences for company 'PT Ratna Utama Karya':
# +------------------+------------+-------------+
# | Field            | DB Value   | CSV Value   |
# +==================+============+=============+
# | operation_kabkot |            | Berau       |
# +------------------+------------+-------------+
#
# Differences for company 'PT Sriwijaya Muba Logistik':
# +---------------+---------------------+-------------------------------------------------------------------------------------------------+
# | Field         | DB Value            | CSV Value                                                                                       |
# +===============+=====================+=================================================================================================+
# | company_type  | Logistics           | Contractor                                                                                      |
# +---------------+---------------------+-------------------------------------------------------------------------------------------------+
# | key_operation | Logistic Management | Mining Services                                                                                 |
# +---------------+---------------------+-------------------------------------------------------------------------------------------------+
# | activities    |                     | ["Trading", "Construction", "Transportation", "Workshop", "Printing", "industry", "Agriculture" |
# +---------------+---------------------+-------------------------------------------------------------------------------------------------+
#
# Differences for company 'PT Sriwijaya Mitra Pelayaran':
# +--------------+------------+-------------+
# | Field        | DB Value   | CSV Value   |
# +==============+============+=============+
# | company_type | Logistics  | Contractor  |
# +--------------+------------+-------------+
#
# Differences for company 'PT Sriwijaya Bara Logistic':
# +--------------+------------+-------------+
# | Field        | DB Value   | CSV Value   |
# +==============+============+=============+
# | company_type | Logistics  | Contractor  |
# +--------------+------------+-------------+
#
# Differences for company 'PT Musi Mitra Jaya':
# +--------------+------------+-------------+
# | Field        | DB Value   | CSV Value   |
# +==============+============+=============+
# | company_type | Logistics  | Contractor  |
# +--------------+------------+-------------+
#
# Differences for company 'PT Aquela Pratama Indonesia':
# +--------------+------------+-------------+
# | Field        | DB Value   | CSV Value   |
# +==============+============+=============+
# | company_type | Holding    | Trader      |
# +--------------+------------+-------------+
#
# Differences for company 'PT Karimata Multi Prima':
# +---------------+------------+--------------+
# | Field         | DB Value   | CSV Value    |
# +===============+============+==============+
# | key_operation | Trading    | Coal Trading |
# +---------------+------------+--------------+
#
# Differences for company 'PT Nusantara Mapan Lestari':
# +---------------+------------+--------------+
# | Field         | DB Value   | CSV Value    |
# +===============+============+==============+
# | key_operation | Trading    | Coal Trading |
# +---------------+------------+--------------+
#
# Differences for company 'PT Hanson Energi Baturaja':
# +---------------+------------+--------------+
# | Field         | DB Value   | CSV Value    |
# +===============+============+==============+
# | key_operation | Trading    | Coal Trading |
# +---------------+------------+--------------+
